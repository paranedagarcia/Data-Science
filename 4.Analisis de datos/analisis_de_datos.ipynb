# %% [markdown]
# # 📊 Análisis de Datos con Pandas y Numpy
# **Objetivo del módulo:** Aprender a manipular y analizar datasets.
#
# **Resultados de Aprendizaje:**
# - Crear y transformar DataFrames.
# - Limpiar y preparar datos.
#
# **Contenidos:**
# 1. Numpy arrays y operaciones
# 2. Introducción a Pandas
# 3. Limpieza: nulos, duplicados, tipos
# 4. Lectura y escritura de archivos
# 5. Exploración, transformación y limpieza con pandas
# 6. Transformaciones: merge, pivot, apply
# 7. EDA:Correlaciones, segmentación y valores atípicos, Análisis automático

# %%
## Diccionario de datos
Detalle de las columnas de la tabla ventas.csv

| COLUMNA                  | DESCRIPCION                           |
|--------------------------|---------------------------------------|
| COTIZACION               | Número de cotización                  |
| RESERVA                  | Número de reserva                     |
| RAZON_COMPRA             | Razón de compra                       |
| FORMA_PAGO               | Forma de pago                         |
| GRUPO_LLEGADA            | Grupo de llegada                      |
| MEDIO_LLEGADA            | Medio de llegada                      |
| ORIGEN_VENTA             | Origen de venta                       |
| ORIGEN_VISITA            | Origen de visita                      |
| UNIDAD                   | Número de la unidad (departamento)    |
| PISO                     | Número de piso                        |
| ORIENTACION              | Orientación del departamento          |
| TIPOLOGIA                | Tipología                             |
| METROS                   | Metros cuadrados                      |
| PRECIO                   | Precio                                |
| DESCUENTO                | Descuento sobre el precio             |
| ESTADO                   | Estado                                |
| ESTADO_PRODUCTO          | Estado del producto                   |
| FECHA_VISITA             | Fecha de visita                       |
| FECHA_COTIZACION         | Fecha de cotización                   |
| FECHA_RESERVA            | Fecha de reserva                      |
| FECHA_PROMESA            | Fecha de promesa                      |
| FECHA_RESCILIACION       | Fecha de resciliación                 |
| FECHA_ESCRITURACION      | Fecha de escrituración                |
| FECHA_AGENDADA           | Fecha de agendada                     |
| FECHA_ENTREGA            | Fecha de entrega del departamento     |
| DIAS_COTIZACION          | Días de cotización                    |
| DIAS_RESERVA             | Días de reserva                       |
| DIAS_PROMESA             | Días de promesa                       |
| DIAS_ESCRITURACION       | Días de escrituración                 |
| DIAS_ENTREGA             | Días de entrega                       |
| PROYECTO                 | Nombre del proyecto                   |
| IDPROYECTO               | ID del proyecto                       |
| DIRECCION                | Dirección (calle y número)            |
| COMUNA                   | Comuna del proyecto                   |
| REGION_PROYECTO          | Región del proyecto                   |
| LATITUD                  | Latitud                               |
| LONGITUD                 | Longitud                              |
| MOTIVO_RESCILIACION      | Motivo de resciliación                |
| BANCO_HIPOTECARIO        | Banco hipotecario                     |
| PAGO_CONTADO             | Pago al contado                       |
| MOTIVO_DESISTIMIENTO     | Motivo de desistimiento               |
| SubMotivoDesistimiento   | Submotivo de desistimiento            |
| COMUNA_PROYECTO          | Comuna del proyecto                   |
| FECHA_LIBERACION         | Fecha de liberación                   |
| CLIENTE                  | Identificación del Cliente            |
| NACIMIENTO               | Fecha de nacimiento                   |
| EDAD                     | Edad                                  |
| SEXO                     | Sexo                                  |
| ESTADO_CIVIL             | Estado civil                          |
| HIJOS                    | Número de hijos                       |
| OCUPACION                | Ocupación                             |
| NACIONALIDAD             | Nacionalidad del cliente              |
| COMUNA_CLIENTE           | Comuna del cliente                    |
| REGION                   | Región del cliente                    |
| INGRESO                  | Nivel de ingresos                     |

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("../data/ventas.csv")
# Out:
# /var/folders/n1/zsbrkfs97sd_4fdl4mnf21g00000gn/T/ipykernel_25223/3996752193.py:4: DtypeWarning: Columns (13,22,23,24,35,38,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/ventas.csv")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       2 import pandas as pd
#       4 df = pd.read_csv("../data/ventas.csv")
# ----> 5 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# cuantas filas y columnas tiene el DataFrame
df.shape
# Out:
# (444643, 52)

# %%
df.head(10)
# Out:
#    COTIZACION  RESERVA RAZON_COMPRA                       FORMA_PAGO  \
# 0           1      1.0    INVERSION                   PIE CUOTAS/HIP
# 1           2      2.0    INVERSION           PIE CUOTAS/PIE CONTADO
# 2           3      3.0    INVERSION                   PIE CUOTAS/HIP
# 3           4      4.0    INVERSION                   PIE CUOTAS/HIP
# 4           5      5.0    INVERSION           PIE CUOTAS/PIE CONTADO
# 5           6      6.0    INVERSION                   PIE CUOTAS/HIP
# 6           7      7.0    INVERSION   PIE CUOTAS/PIE CONTADO/HIP/BON
# 7           8      8.0    INVERSION                   PIE CUOTAS/HIP
# 8           9      9.0    INVERSION                   PIE CUOTAS/HIP
# 9          10     10.0    INVERSION                   PIE CUOTAS/HIP
#
#    GRUPO_LLEGADA MEDIO_LLEGADA ORIGEN_VENTA ORIGEN_VISITA UNIDAD  PISO  ...  \
# 0  CARGA INICIAL     MIGRACION      Interna     Distancia    205     2  ...
# 1  CARGA INICIAL     MIGRACION      Interna     Distancia    206     2  ...
# 2  CARGA INICIAL     MIGRACION      Interna     Distancia    302     3  ...
# 3  CARGA INICIAL     MIGRACION      Interna     Distancia    303     3  ...
# 4  CARGA INICIAL     MIGRACION      Interna     Distancia    306     3  ...
# 5  CARGA INICIAL     MIGRACION      Interna     Distancia    403     4  ...
# 6  CARGA INICIAL     MIGRACION      Interna     Distancia    404     4  ...
# 7  CARGA INICIAL     MIGRACION      Interna     Distancia    405     4  ...
# 8  CARGA INICIAL     MIGRACION      Interna     Distancia    501     5  ...
# 9  CARGA INICIAL     MIGRACION      Interna     Distancia    502     5  ...
#
#   NACIMIENTO EDAD SEXO ESTADO_CIVIL HIJOS  OCUPACION NACIONALIDAD  \
# 0        NaN  NaN    F          NaN   NaN        NaN        Chile
# 1        NaN  NaN    M          NaN   NaN        NaN        Chile
# 2        NaN  NaN    F          NaN   NaN        NaN        Chile
# 3        NaN  NaN    M          NaN   NaN        NaN        Chile
# 4        NaN  NaN    F          NaN   NaN        NaN        Chile
# 5        NaN  NaN    M          NaN   NaN        NaN        Chile
# 6        NaN  NaN    F          NaN   NaN        NaN        Chile
# 7        NaN  NaN    M          NaN   NaN        NaN        Chile
# 8        NaN  NaN    F          NaN   NaN        NaN        Chile
# 9        NaN  NaN    M          NaN   NaN        NaN        Chile
#
#      COMUNA_CLIENTE                REGION                  INGRESO
# 0          La Reina  REGIÓN METROPOLITANA           0 - $1.000.000
# 1          La Reina  REGIÓN METROPOLITANA  $3.000.001 - $4.000.000
# 2       Providencia  REGIÓN METROPOLITANA             NO INFORMADO
# 3   Sin Informacion  REGIÓN METROPOLITANA           0 - $1.000.000
# 4          La Reina  REGIÓN METROPOLITANA           0 - $1.000.000
# 5         Peñalolén  REGIÓN METROPOLITANA        Más de $3.000.000
# 6          Vitacura  REGIÓN METROPOLITANA           0 - $1.000.000
# 7   Sin Informacion  REGIÓN METROPOLITANA           0 - $1.000.000
# 8  Estación Central  REGIÓN METROPOLITANA           0 - $1.000.000
# 9          Santiago  REGIÓN METROPOLITANA             NO INFORMADO
#
# [10 rows x 52 columns]
